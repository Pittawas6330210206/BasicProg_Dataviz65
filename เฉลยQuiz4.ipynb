# %% [markdown]
# <a href="https://colab.research.google.com/github/Pittawas6330210206/BasicProg_Dataviz65/blob/main/%E0%B9%80%E0%B8%89%E0%B8%A5%E0%B8%A2Quiz4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ## Mete Data = Data that describes data
# ## CSV = comma separated Value

# %% [markdown]
# # นำเข้า data
#   -Up load colab
#
#  -link whit google drive

# %%
data0 = pd.read_csv('/opendata_project.csv')

# %% [markdown]
# ดูหัวตาราง

# %%
data0.head()
# Out:
#    row_number                project_id                             name_en  \
# 0      7880.0  5ee08d64dda791001299b2a6  Winning Residence Sukhumvit Praksa
# 1     16689.0             project_11326                    Gift Condominium
# 2       290.0  62739c4089233e001362b001    Sanrak 9 Sukprayoon Nong Krathum
# 3     20719.0              project_2010                     Baan Sansabai 1
# 4       199.0             project_16838          Baanpruksa Ratchapruek-345
#
#                               name_th propertytype_id propertytype_name_en  \
# 0  วินนิ่ง เรสซิเดนท์ สุขุมวิท แพรกษา               1       Detached House
# 1                 กิ๊ฟท์ คอนโดมิเนียม               2                Condo
# 2      แสนรัก 9 ศุขประยูร หนองกระทุ่ม               3             Townhome
# 3                       บ้านแสนสบาย 1               1       Detached House
# 4              บ้านพฤกษา ราชพฤกษ์-345               3             Townhome
#
#   propertytype_name_th  price_min     developer_id  \
# ...

# %%
data1 = pd.read_csv('/opendata_unittype.csv')

# %%
data1.head()
# Out:
#    row_number     unittype_id    project_id             name_th  \
# 0       27501   unittype_9565  project_2446           2 Bedroom
# 1       28777  unittype_10267  project_3543  บ้านแฝดสองชั้น Z-2
# 2       28865    unittype_471   project_143    1 Bedroom Type B
# 3       24988  unittype_19506  project_7766    Studio Floor 1-2
# 4       38596  unittype_10290  project_3551                TH 3
#
#    propertytype_id propertytype_name_en propertytype_name_th  \
# 0                2                Condo                คอนโด
# 1            20000           Twin house              บ้านแฝด
# 2                2                Condo                คอนโด
# 3                2                Condo                คอนโด
# 4                3             Townhome             ทาวน์โฮม
#
#    area_total_min_wa  area_usable_min  price_min  ...  count_room_guest  \
# 0                NaN             37.3  2500000.0  ...               1.0
# ...

# %% [markdown]
# # link whit google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data2 = pd.read_csv('/content/drive/MyDrive/DPDV65/opendata_unittype.csv')
data2.head()
# Out:
#    row_number     unittype_id    project_id             name_th  \
# 0       27501   unittype_9565  project_2446           2 Bedroom
# 1       28777  unittype_10267  project_3543  บ้านแฝดสองชั้น Z-2
# 2       28865    unittype_471   project_143    1 Bedroom Type B
# 3       24988  unittype_19506  project_7766    Studio Floor 1-2
# 4       38596  unittype_10290  project_3551                TH 3
#
#    propertytype_id propertytype_name_en propertytype_name_th  \
# 0                2                Condo                คอนโด
# 1            20000           Twin house              บ้านแฝด
# 2                2                Condo                คอนโด
# 3                2                Condo                คอนโด
# 4                3             Townhome             ทาวน์โฮม
#
#    area_total_min_wa  area_usable_min  price_min  ...  count_room_guest  \
# 0                NaN             37.3  2500000.0  ...               1.0
# ...

# %%
data2.tail(10)
# Out:
#        row_number               unittype_id                project_id  \
# 42615       36172            unittype_34140             project_14663
# 42616       28981            unittype_25373             project_10133
# 42617       35109             unittype_1459               project_711
# 42618       22299            unittype_13674              project_5356
# 42619       11944            unittype_34884             project_15005
# 42620       37109            unittype_38508             project_16864
# 42621          14            unittype_14016              project_5275
# 42622       41009  617bde1687dd2300149d2195  617bdd47f62011001350de07
# 42623        9333            unittype_37375             project_16389
# 42624         780            unittype_17011              project_6762
#
#                    name_th  propertytype_id propertytype_name_en  \
# 42615            2 Bedroom                2                Condo
# ...

# %%
data2.shape
# Out:
# (42625, 27)

# %% [markdown]
# ## Explore data

# %%
data2.describe()
# Out:
#          row_number  propertytype_id  area_total_min_wa  area_usable_min  \
# count  42625.000000     42625.000000        3747.000000     36999.000000
# mean   21313.000000       938.471859          44.413819       139.286943
# std    12304.921949      4220.823322          21.502884       111.939963
# min        1.000000         1.000000           1.000000        14.000000
# 25%    10657.000000         1.000000          23.000000        60.000000
# 50%    21313.000000         2.000000          50.000000       125.000000
# 75%    31969.000000         3.000000          60.000000       179.000000
# max    42625.000000     20000.000000         335.000000      4350.000000
#
#           price_min  count_airconditioner  count_elevator  \
# count  3.542800e+04           1780.000000             0.0
# mean   5.569699e+06              2.465730             NaN
# std    1.117088e+07              1.512717             NaN
# min    1.000000e+05              1.000000             NaN
# ...

# %% [markdown]
# NaN  = not of number ไม่มีตัวเลข

# %% [markdown]
# # ชี้ค่าในตาราง
# -ในตารางTail

# %%
data2['propertytype_name_en']
# Out:
# 0                 Condo
# 1            Twin house
# 2                 Condo
# 3                 Condo
# 4              Townhome
#               ...
# 42620    Detached House
# 42621    Detached House
# 42622          Townhome
# 42623    Detached House
# 42624    Detached House
# Name: propertytype_name_en, Length: 42625, dtype: object

# %%
data2['propertytype_name_en'][42619]
# Out:
# 'Detached House'

# %% [markdown]
# # .iloc

# %%
data2.iloc[42619,5]
# Out:
# 'Detached House'

# %%
data2.iloc[-6,5]
# Out:
# 'Detached House'

# %% [markdown]
# # Table slicing

# %%
data2.iloc[-20:,7:10]
# Out:
#        area_total_min_wa  area_usable_min   price_min
# 42605                NaN              NaN   1300000.0
# 42606                NaN            349.0  18000000.0
# 42607                NaN             71.0  17000000.0
# 42608                NaN              NaN         NaN
# 42609                NaN              NaN         NaN
# 42610                NaN            250.0   5990000.0
# 42611                NaN              NaN         NaN
# 42612                NaN            154.0   4800000.0
# 42613               50.0            105.0   1900000.0
# 42614                NaN            142.1   4880000.0
# 42615                NaN             60.0   3500000.0
# 42616                NaN            200.0         NaN
# 42617                NaN              NaN         NaN
# 42618                NaN            130.0  36500000.0
# 42619                NaN            353.0  23590000.0
# 42620                NaN            157.0         NaN
# ...

# %% [markdown]
# # Table Query

# %%
data2[data2['propertytype_name_en']=='Condo']
# Out:
#        row_number     unittype_id     project_id                      name_th  \
# 0           27501   unittype_9565   project_2446                    2 Bedroom
# 2           28865    unittype_471    project_143             1 Bedroom Type B
# 3           24988  unittype_19506   project_7766             Studio Floor 1-2
# 10           5238  unittype_15162   project_4107             Studio Floor 5-8
# 14          29911  unittype_25780  project_10313                    1 Bedroom
# ...           ...             ...            ...                          ...
# 42590       23548  unittype_15279   project_3976  1 Bedroom Tower 1 Floor 5-6
# 42602       39384   unittype_3476    project_812             2 Bedroom Type A
# 42604        1058   unittype_7949   project_2641            Typical 1 Bedroom
# 42607       13546  unittype_40152  project_17505                    2 Bedroom
# 42615       36172  unittype_34140  project_14663                    2 Bedroom
#
# ...

# %%
data2['propertytype_name_en']=='Condo'
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4        False
#          ...
# 42620    False
# 42621    False
# 42622    False
# 42623    False
# 42624    False
# Name: propertytype_name_en, Length: 42625, dtype: bool

# %%
data2[data2['price_min']>10000000].describe()
# Out:
#          row_number  propertytype_id  area_total_min_wa  area_usable_min  \
# count   3481.000000      3481.000000         304.000000      3354.000000
# mean   21066.205401       215.859523          52.622796       286.948606
# std    12478.117102      2035.944151          31.406177       185.081647
# min        1.000000         1.000000           1.000000        30.000000
# 25%     9796.000000         1.000000          30.000000       155.000000
# 50%    21525.000000         1.000000          51.400000       265.000000
# 75%    32420.000000         2.000000          72.625000       362.750000
# max    42620.000000     20000.000000         335.000000      2548.000000
#
#           price_min  count_airconditioner  count_elevator  \
# count  3.481000e+03            138.000000             0.0
# mean   2.577675e+07              4.536232             NaN
# std    2.789259e+07              2.015123             NaN
# min    1.003000e+07              1.000000             NaN
# ...

# %% [markdown]
# ## Quiz 4
#   1.ราคาเฉลี่ยที่มีราคาระหว่าง 3-5 ล้านบาท
#
#   2.พื้นที่ของห้องและจำนวนห้องนอนของบ้านที่แพงที่สุด
#
#   3.จำนวนที่จอดรถและห้องน้ำของบ้านที่ถูกที่สุด
#
#   4.ชนิดของบ้านที่แพงที่สุด
#
#   5.บ้านชนิดไหนมีปริมาณมากที่สุด

# %%
#1
data2[(data2['price_min'] >=3000000) & (data2['price_min'] <= 5000000)].describe()
# Out:
#          row_number  propertytype_id  area_total_min_wa  area_usable_min  \
# count   8943.000000      8943.000000        1066.000000      8148.000000
# mean   21153.925976      1285.383987          46.709559       138.785306
# std    12338.077057      4901.447720          18.555223        66.760066
# min        2.000000         1.000000           2.000000        20.100000
# 25%    10042.500000         1.000000          30.000000        96.000000
# 50%    21864.000000         2.000000          50.000000       145.000000
# 75%    32198.000000         3.000000          60.000000       178.000000
# max    42617.000000     20000.000000          99.000000       896.000000
#
#           price_min  count_airconditioner  count_elevator  \
# count  8.943000e+03            418.000000             0.0
# mean   3.922594e+06              2.653110             NaN
# std    5.847665e+05              1.128124             NaN
# min    3.000000e+06              1.000000             NaN
# ...

# %%
data2[(data2['price_min'] >=3000000) & (data2['price_min'] <= 5000000)] .mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# row_number              2.115393e+04
# propertytype_id         1.285384e+03
# area_total_min_wa       4.670956e+01
# area_usable_min         1.387853e+02
# price_min               3.922594e+06
# count_airconditioner    2.653110e+00
# count_elevator                   NaN
# count_floor_internal    2.132716e+00
# count_parking           1.877722e+00
# count_room_bath         2.406904e+00
# count_room_bed          2.736634e+00
# count_room_dinning      1.001520e+00
# count_room_guest        1.005557e+00
# count_room_kitchen      1.016489e+00
# count_room_living       1.028018e+00
# count_room_maid         1.033333e+00
# count_room_storage      1.038430e+00
# ...

# %%
data2['price_min']<5000000
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 42620    False
# 42621    False
# 42622    False
# 42623     True
# 42624     True
# Name: price_min, Length: 42625, dtype: bool

# %%
data2['price_min']>3000000
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 42620    False
# 42621     True
# 42622    False
# 42623     True
# 42624     True
# Name: price_min, Length: 42625, dtype: bool

# %%
#2
data2[data2['price_min']==580000000][['area_usable_min','count_room_bed']]
# Out:
#        area_usable_min  count_room_bed
# 33122           1182.0             3.0

# %%
data2['price_min'].max()
# Out:
# 580000000.0

# %%
data2[data2['price_min']==data2['price_min'].max()]
# Out:
#        row_number     unittype_id     project_id    name_th  propertytype_id  \
# 33122        8629  unittype_37324  project_16305  Penthouse                2
#
#       propertytype_name_en propertytype_name_th  area_total_min_wa  \
# 33122                Condo                คอนโด                NaN
#
#        area_usable_min    price_min  ...  count_room_guest  \
# 33122           1182.0  580000000.0  ...               NaN
#
#        count_room_kitchen  count_room_living  count_room_maid  \
# 33122                 NaN                NaN              NaN
#
#        count_room_storage  count_room_utility         date_created  \
# 33122                 NaN                 NaN  2021-11-12 13:20:31
#
#               date_updated  source  \
# 33122  2020-10-14 00:55:50  baania
#
#                                             url_unittype
# 33122  https://baania.com/th/project/เดอะ-สุโขทัย-เรส...
#
# [1 rows x 27 columns]

# %%
data2[data2['price_min']==data2['price_min'].max()][['propertytype_name_en','propertytype_name_en','count_room_bed','price_min']]
# Out:
#       propertytype_name_en propertytype_name_en  count_room_bed    price_min
# 33122                Condo                Condo             3.0  580000000.0

# %%
#3
data2[data2['price_min']==100000][['count_parking','count_room_bath']]
# Out:
#        count_parking  count_room_bath
# 8640             NaN              1.0
# 11019            NaN              1.0
# 17941            NaN              1.0
# 30364            NaN              1.0

# %%
data2['price_min'].min()
# Out:
# 100000.0

# %%
data2[data2['price_min']==data2['price_min'].min()]
# Out:
#        row_number     unittype_id    project_id    name_th  propertytype_id  \
# 8640        28996  unittype_18085  project_7286  1 Bedroom                2
# 11019         808  unittype_18253  project_7374  1 Bedroom                2
# 17941       29386  unittype_19041  project_7623  1 Bedroom                2
# 30364         490  unittype_15924  project_6214     Studio                2
#
#       propertytype_name_en propertytype_name_th  area_total_min_wa  \
# 8640                 Condo                คอนโด                NaN
# 11019                Condo                คอนโด                NaN
# 17941                Condo                คอนโด                NaN
# 30364                Condo                คอนโด                NaN
#
#        area_usable_min  price_min  ...  count_room_guest  count_room_kitchen  \
# 8640              33.0   100000.0  ...               NaN                 NaN
# 11019             24.0   100000.0  ...               NaN                 NaN
# ...

# %%
data2[data2['price_min']==data2['price_min'].min()][['propertytype_name_en','propertytype_name_en','count_room_bed','price_min']]
# Out:
#       propertytype_name_en propertytype_name_en  count_room_bed  price_min
# 8640                 Condo                Condo             1.0   100000.0
# 11019                Condo                Condo             1.0   100000.0
# 17941                Condo                Condo             1.0   100000.0
# 30364                Condo                Condo             0.0   100000.0

# %%
#4
data2[data2['price_min']==data2['price_min'].max()][['propertytype_name_en','price_min']]
# Out:
#       propertytype_name_en    price_min
# 33122                Condo  580000000.0

# %%
#5
data2['propertytype_name_en'].describe()
# Out:
# count              42625
# unique                11
# top       Detached House
# freq               17670
# Name: propertytype_name_en, dtype: object
